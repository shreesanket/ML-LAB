# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
tickers = ["RELIANCE.NS", "TCS.NS", "INFY.NS"]

# Fetch historical data for the last 1 year
data = yf.download(tickers, start="2022-10-01", end="2023-10-01", group_by='ticker')

# Display the first 5 rows of the dataset
print("First 5 rows of the dataset:")
print(data.head())

print("\nShape of the dataset:")
print(data.shape)

# Check column names
print("\nColumn names:")
print(data.columns)

# Summary statistics for a specific stock (e.g., Reliance)
reliance_data = data['RELIANCE.NS']
print("\nSummary statistics for Reliance Industries:")
print(reliance_data.describe())

# Calculate daily returns
reliance_data['Daily Return'] = reliance_data['Close'].pct_change()
print(reliance_data)
# Out:
# [*********************100%***********************]  3 of 3 completed
# First 5 rows of the dataset:
# Ticker           TCS.NS                                                  \
# Price              Open         High          Low        Close   Volume
# Date
# 2022-10-03  2894.197390  2919.032359  2873.904187  2884.485596  1763331
# 2022-10-04  2927.970939  2993.730628  2921.254903  2987.111084  2145875
# 2022-10-06  3006.293059  3018.855518  2988.367349  2997.547607  1790816
# 2022-10-07  2993.150777  3000.495078  2955.173685  2961.744629  1939879
# 2022-10-10  2908.692057  3021.754173  2903.860342  3013.588623  3064063
#
# Ticker          INFY.NS                                                  \
# Price              Open         High          Low        Close   Volume
# Date
# 2022-10-03  1337.743116  1337.743116  1313.110452  1320.452881  4943169
# 2022-10-04  1345.038322  1356.928368  1339.638130  1354.228271  6631341
# ...

# %%
plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
reliance_data['Close'].plot(title="Reliance Industries - Closing Price")
plt.subplot(2, 1, 2)
reliance_data['Daily Return'].plot(title="Reliance Industries - Daily Returns", color='orange')
plt.tight_layout()
plt.show()

# %%
file_path = 'data.csv'  # Ensure the file exists in the same directory
    df = pd.read_csv(f)
    print("Sample data:")
    print(df.head())
    print("\n")
# Out:
# Reliance stock data saved to 'reliance_stock_data.csv'.

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Define stock tickers
tickers = ["HDFCBANK.NS", "ICICIBANK.NS", "KOTAKBANK.NS"]

# Fetch historical data for the last 1 year
data = yf.download(tickers, start="2023-10-01", end="2024-10-01", group_by='ticker')

# Get the HDFC data
HDFC_Data = data['HDFCBANK.NS']

# Calculate daily returns
HDFC_Data['Daily Return'] = HDFC_Data['Close'].pct_change()

# Create the plots
plt.figure(figsize=(12, 6))

# Plot closing prices
plt.subplot(2, 1, 1)
HDFC_Data['Close'].plot(title="HDFC Bank - Closing Price")

# Plot daily returns
plt.subplot(2, 1, 2)
HDFC_Data['Daily Return'].plot(title="HDFC Bank - Daily Returns", color='orange')

# Adjust layout and display the plots
plt.tight_layout()
plt.show()


ICICIBANK_Data = data['ICICIBANK.NS']

# Calculate daily returns
ICICIBANK_Data['Daily Return'] = ICICIBANK_Data['Close'].pct_change()

# Create the plots
plt.figure(figsize=(12, 6))

# Plot closing prices
plt.subplot(2, 1, 1)
ICICIBANK_Data['Close'].plot(title="ICICIBANK_Data Bank - Closing Price")

# Plot daily returns
plt.subplot(2, 1, 2)
ICICIBANK_Data['Daily Return'].plot(title="ICICIBANK_Data Bank - Daily Returns", color='orange')

# Adjust layout and display the plots
plt.tight_layout()
plt.show()

KOTAKBANK_Data = data['KOTAKBANK.NS']

# Calculate daily returns
KOTAKBANK_Data['Daily Return'] = KOTAKBANK_Data['Close'].pct_change()

# Create the plots
plt.figure(figsize=(12, 6))

# Plot closing prices
plt.subplot(2, 1, 1)
KOTAKBANK_Data['Close'].plot(title="KOTAKBANK_Data Bank - Closing Price")

# Plot daily returns
plt.subplot(2, 1, 2)
KOTAKBANK_Data['Daily Return'].plot(title="KOTAKBANK_Data Bank - Daily Returns", color='orange')

# Adjust layout and display the plots
plt.tight_layout()
plt.show()
# Out:
# [*********************100%***********************]  3 of 3 completed
# <ipython-input-43-584c16174af0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HDFC_Data['Daily Return'] = HDFC_Data['Close'].pct_change()
# <ipython-input-43-584c16174af0>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ICICIBANK_Data['Daily Return'] = ICICIBANK_Data['Close'].pct_change()
# <ipython-input-43-584c16174af0>:56: SettingWithCopyWarning:
# ...

# %%
import pandas as pd
# Create a DataFrame directly from a dictionary
data = {
    'USN': ['1BM22CS271','1BM22CS890','1BM22CS453','1BM22CS078','1BM22CS450'],
    'Name': ['Alice', 'Bob', 'Charlie', 'David','Jon'],
    'Marks': [85, 90, 95, 92,82]
}
df = pd.DataFrame(data)
print("Sample data:")
print(df.head())
# Out:
# Sample data:
#           USN     Name  Marks
# 0  1BM22CS271    Alice     85
# 1  1BM22CS890      Bob     90
# 2  1BM22CS453  Charlie     95
# 3  1BM22CS078    David     92
# 4  1BM22CS450      Jon     82

# %%
from sklearn.datasets import load_diabetes
import pandas as pd

# Load the diabetes dataset
diabetes = load_diabetes()

# Create a DataFrame using the features and target
df = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
df['target'] = diabetes.target

# Display the first few rows
print("Sample data:")
print(df.head())
# Out:
# Sample data:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
file_path = 'data.csv'  # Ensure the file exists in the same directory
df = pd.read_csv("/content/sample_sales_data.csv")
print("Sample data:")
print(df.head())
print("\n")
# Out:
# Sample data:
#     Product  Quantity  Price  Sales Region
# 0    Laptop         5   1000   5000  North
# 1     Mouse        15     20    300   West
# 2  Keyboard        10     50    500   East
# 3   Monitor         8    200   1600  South
# 4    Laptop        12    950  11400  North

# %%
df = pd.read_csv('/content/Diabeties.csv')
print("Sample data:")
print(df.head())
# Out:
# Sample data:
#     ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0  502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1  735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2  420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4  504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
#
#     BMI CLASS
# 0  24.0     N
# 1  23.0     N
# 2  24.0     N
# 3  24.0     N
# 4  21.0     N

# %% [markdown]
# # New Section
